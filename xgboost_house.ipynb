# %%
import pandas as pd
import numpy as np
from sklearn import datasets
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
import xgboost as xgb
from sklearn.metrics import r2_score
from sklearn.metrics import root_mean_squared_error

# %%
housingX, housingy = datasets.fetch_california_housing (
    return_X_y=True, as_frame=True
)
housingX.head()
# Out:
#    MedInc  HouseAge  AveRooms  AveBedrms  Population  AveOccup  Latitude  \
# 0  8.3252      41.0  6.984127   1.023810       322.0  2.555556     37.88
# 1  8.3014      21.0  6.238137   0.971880      2401.0  2.109842     37.86
# 2  7.2574      52.0  8.288136   1.073446       496.0  2.802260     37.85
# 3  5.6431      52.0  5.817352   1.073059       558.0  2.547945     37.85
# 4  3.8462      52.0  6.281853   1.081081       565.0  2.181467     37.85
#
#    Longitude
# 0    -122.23
# 1    -122.22
# 2    -122.24
# 3    -122.25
# 4    -122.25

# %%
sns.set_palette("dark:grey")
sns.displot(housingy, kind="hist")

# %%
graphx = sns.pairplot(housingX)

# %%
housingxy = pd.concat([housingy, housingX], axis=1)
graphxy = sns.pairplot(housingxy)

# %%
X_train, X_test, y_train, y_test = train_test_split(
    housingX, housingy, test_size=0.2, random_state=17
)
X_test.head()
# Out:
#        MedInc  HouseAge  AveRooms  AveBedrms  Population  AveOccup  Latitude  \
# 18403  5.4741      24.0  6.587799   1.060181      4017.0  3.311624     37.24
# 13405  1.9583       7.0  5.362805   1.442073      1064.0  3.243902     34.10
# 9539   2.6058      40.0  3.885714   0.914286       785.0  4.485714     37.39
# 8668   4.5817      30.0  4.146135   1.108696      1526.0  1.842995     33.82
# 9019   8.0137       9.0  7.734673   1.041211     12873.0  3.274739     34.16
#
#        Longitude
# 18403    -121.84
# 13405    -117.46
# 9539     -120.71
# 8668     -118.39
# 9019     -118.78

# %%
housevalue_regressor = xgb.XGBRegressor()
housevalue_regressor.fit(
    X_train,y_train,
    eval_set=[(X_test, y_test),(X_train,y_train)]
)
# Out:
# [0]	validation_0-rmse:0.93417	validation_1-rmse:0.93744
# [1]	validation_0-rmse:0.80544	validation_1-rmse:0.79501
# [2]	validation_0-rmse:0.72406	validation_1-rmse:0.70244
# [3]	validation_0-rmse:0.66749	validation_1-rmse:0.63818
# [4]	validation_0-rmse:0.63751	validation_1-rmse:0.60033
# [5]	validation_0-rmse:0.61189	validation_1-rmse:0.56644
# [6]	validation_0-rmse:0.58620	validation_1-rmse:0.53308
# [7]	validation_0-rmse:0.57241	validation_1-rmse:0.51228
# [8]	validation_0-rmse:0.56593	validation_1-rmse:0.50156
# [9]	validation_0-rmse:0.55121	validation_1-rmse:0.48426
# [10]	validation_0-rmse:0.54240	validation_1-rmse:0.47137
# [11]	validation_0-rmse:0.53708	validation_1-rmse:0.46342
# [12]	validation_0-rmse:0.53323	validation_1-rmse:0.45607
# [13]	validation_0-rmse:0.53001	validation_1-rmse:0.45001
# [14]	validation_0-rmse:0.52530	validation_1-rmse:0.44200
# [15]	validation_0-rmse:0.52239	validation_1-rmse:0.43719
# [16]	validation_0-rmse:0.52073	validation_1-rmse:0.43158
# [17]	validation_0-rmse:0.51860	validation_1-rmse:0.42724
# [18]	validation_0-rmse:0.51637	validation_1-rmse:0.42247
# [19]	validation_0-rmse:0.51328	validation_1-rmse:0.41829
# [20]	validation_0-rmse:0.51067	validation_1-rmse:0.41347
# [21]	validation_0-rmse:0.51055	validation_1-rmse:0.40934
# [22]	validation_0-rmse:0.51002	validation_1-rmse:0.40499
# [23]	validation_0-rmse:0.50888	validation_1-rmse:0.40238
# [24]	validation_0-rmse:0.50835	validation_1-rmse:0.39935
# [25]	validation_0-rmse:0.50691	validation_1-rmse:0.39720
# [26]	validation_0-rmse:0.50664	validation_1-rmse:0.39356
# [27]	validation_0-rmse:0.50668	validation_1-rmse:0.39145
# [28]	validation_0-rmse:0.50628	validation_1-rmse:0.38824
# [29]	validation_0-rmse:0.50541	validation_1-rmse:0.38403
# [30]	validation_0-rmse:0.50479	validation_1-rmse:0.38129
# [31]	validation_0-rmse:0.50276	validation_1-rmse:0.37801
# [32]	validation_0-rmse:0.50314	validation_1-rmse:0.37575
# [33]	validation_0-rmse:0.50321	validation_1-rmse:0.37350
# [34]	validation_0-rmse:0.50253	validation_1-rmse:0.37102
# [35]	validation_0-rmse:0.50270	validation_1-rmse:0.36999
# [36]	validation_0-rmse:0.50200	validation_1-rmse:0.36718
# [37]	validation_0-rmse:0.49951	validation_1-rmse:0.36330
# [38]	validation_0-rmse:0.49895	validation_1-rmse:0.36145
# [39]	validation_0-rmse:0.49827	validation_1-rmse:0.35863
# [40]	validation_0-rmse:0.49837	validation_1-rmse:0.35615
# [41]	validation_0-rmse:0.49759	validation_1-rmse:0.35328
# [42]	validation_0-rmse:0.49766	validation_1-rmse:0.35253
# [43]	validation_0-rmse:0.49685	validation_1-rmse:0.34976
# [44]	validation_0-rmse:0.49675	validation_1-rmse:0.34789
# [45]	validation_0-rmse:0.49739	validation_1-rmse:0.34602
# [46]	validation_0-rmse:0.49714	validation_1-rmse:0.34476
# [47]	validation_0-rmse:0.49619	validation_1-rmse:0.34281
# [48]	validation_0-rmse:0.49556	validation_1-rmse:0.34089
# [49]	validation_0-rmse:0.49621	validation_1-rmse:0.33874
# [50]	validation_0-rmse:0.49536	validation_1-rmse:0.33601
# [51]	validation_0-rmse:0.49519	validation_1-rmse:0.33389
# [52]	validation_0-rmse:0.49515	validation_1-rmse:0.33261
# [53]	validation_0-rmse:0.49485	validation_1-rmse:0.33170
# [54]	validation_0-rmse:0.49475	validation_1-rmse:0.32966
# [55]	validation_0-rmse:0.49493	validation_1-rmse:0.32875
# [56]	validation_0-rmse:0.49457	validation_1-rmse:0.32672
# [57]	validation_0-rmse:0.49438	validation_1-rmse:0.32508
# [58]	validation_0-rmse:0.49432	validation_1-rmse:0.32379
# [59]	validation_0-rmse:0.49362	validation_1-rmse:0.32274
# [60]	validation_0-rmse:0.49417	validation_1-rmse:0.32100
# [61]	validation_0-rmse:0.49332	validation_1-rmse:0.31836
# [62]	validation_0-rmse:0.49331	validation_1-rmse:0.31612
# [63]	validation_0-rmse:0.49311	validation_1-rmse:0.31466
# [64]	validation_0-rmse:0.49317	validation_1-rmse:0.31332
# [65]	validation_0-rmse:0.49262	validation_1-rmse:0.31104
# [66]	validation_0-rmse:0.49186	validation_1-rmse:0.30887
# [67]	validation_0-rmse:0.49169	validation_1-rmse:0.30716
# [68]	validation_0-rmse:0.49160	validation_1-rmse:0.30671
# [69]	validation_0-rmse:0.49160	validation_1-rmse:0.30616
# [70]	validation_0-rmse:0.49141	validation_1-rmse:0.30450
# [71]	validation_0-rmse:0.49216	validation_1-rmse:0.30293
# [72]	validation_0-rmse:0.49217	validation_1-rmse:0.30136
# [73]	validation_0-rmse:0.49246	validation_1-rmse:0.29944
# [74]	validation_0-rmse:0.49253	validation_1-rmse:0.29836
# [75]	validation_0-rmse:0.49242	validation_1-rmse:0.29793
# [76]	validation_0-rmse:0.49179	validation_1-rmse:0.29611
# [77]	validation_0-rmse:0.49202	validation_1-rmse:0.29501
# [78]	validation_0-rmse:0.49188	validation_1-rmse:0.29367
# [79]	validation_0-rmse:0.49193	validation_1-rmse:0.29206
# [80]	validation_0-rmse:0.49114	validation_1-rmse:0.29015
# [81]	validation_0-rmse:0.49065	validation_1-rmse:0.28931
# [82]	validation_0-rmse:0.49044	validation_1-rmse:0.28808
# [83]	validation_0-rmse:0.49008	validation_1-rmse:0.28632
# [84]	validation_0-rmse:0.49014	validation_1-rmse:0.28529
# [85]	validation_0-rmse:0.48987	validation_1-rmse:0.28470
# [86]	validation_0-rmse:0.48997	validation_1-rmse:0.28337
# [87]	validation_0-rmse:0.49005	validation_1-rmse:0.28265
# [88]	validation_0-rmse:0.49012	validation_1-rmse:0.28185
# [89]	validation_0-rmse:0.49030	validation_1-rmse:0.28075
# [90]	validation_0-rmse:0.49014	validation_1-rmse:0.27983
# [91]	validation_0-rmse:0.49014	validation_1-rmse:0.27930
# [92]	validation_0-rmse:0.48995	validation_1-rmse:0.27787
# [93]	validation_0-rmse:0.48986	validation_1-rmse:0.27707
# [94]	validation_0-rmse:0.48996	validation_1-rmse:0.27647
# [95]	validation_0-rmse:0.48997	validation_1-rmse:0.27493
# [96]	validation_0-rmse:0.48943	validation_1-rmse:0.27403
# [97]	validation_0-rmse:0.48964	validation_1-rmse:0.27282
# [98]	validation_0-rmse:0.48934	validation_1-rmse:0.27189
# [99]	validation_0-rmse:0.48955	validation_1-rmse:0.27120
# XGBRegressor(base_score=None, booster=None, callbacks=None,
#              colsample_bylevel=None, colsample_bynode=None,
#              colsample_bytree=None, device=None, early_stopping_rounds=None,
#              enable_categorical=False, eval_metric=None, feature_types=None,
#              feature_weights=None, gamma=None, grow_policy=None,
#              importance_type=None, interaction_constraints=None,
#              learning_rate=None, max_bin=None, max_cat_threshold=None,
#              max_cat_to_onehot=None, max_delta_step=None, max_depth=None,
#              max_leaves=None, min_child_weight=None, missing=nan,
#              monotone_constraints=None, multi_strategy=None, n_estimators=None,
#              n_jobs=None, num_parallel_tree=None, ...)

# %%
y_score = housevalue_regressor.predict(X_test)
y_score
# Out:
# array([2.8310823 , 0.9903586 , 0.73254323, ..., 2.0474033 , 1.9122106 ,
#        0.8976577 ], shape=(4128,), dtype=float32)

# %%
predicter_r2 = r2_score(y_true=y_test, y_pred=y_score)
print(predicter_r2)
# Out:
# 0.8167135465189188

# %%
predicter_rmse = root_mean_squared_error(
    y_true=y_test, y_pred=y_score
)
print (predicter_rmse)
# Out:
# 0.48955245051753077

# %%
sns.regplot(
    x=y_test, y=y_score,
    scatter_kws={"color": "grey"},
    line_kws={"color": "black"}
)
# Out:
# <Axes: xlabel='MedHouseVal'>

# %%
residuals = y_test - y_score
X_testResiduals = pd.concat([X_test, residuals], axis=1)
X_testResiduals.head()
# Out:
#        MedInc  HouseAge  AveRooms  AveBedrms  Population  AveOccup  Latitude  \
# 18403  5.4741      24.0  6.587799   1.060181      4017.0  3.311624     37.24
# 13405  1.9583       7.0  5.362805   1.442073      1064.0  3.243902     34.10
# 9539   2.6058      40.0  3.885714   0.914286       785.0  4.485714     37.39
# 8668   4.5817      30.0  4.146135   1.108696      1526.0  1.842995     33.82
# 9019   8.0137       9.0  7.734673   1.041211     12873.0  3.274739     34.16
#
#        Longitude  MedHouseVal
# 18403    -121.84    -0.443082
# 13405    -117.46     0.097641
# 9539     -120.71    -0.005543
# 8668     -118.39     0.735812
# 9019     -118.78    -0.051286

# %%
fig, axes = plt.subplots(
    nrows=2, ncols=4, figsize=(24,16), sharey=True)

axes[0,0].scatter(x=X_testResiduals["MedInc"],
    y=X_testResiduals["MedHouseVal"],
    alpha=0.5, color="grey")
axes[0,0].set_title("MedInc")

axes[0,1].scatter(x=X_testResiduals["HouseAge"],
    y=X_testResiduals["MedHouseVal"],
    alpha=0.5, color="grey")
axes[0,1].set_title("HouseAge")

axes[0,2].scatter(x=X_testResiduals["AveRooms"],
    y=X_testResiduals["MedHouseVal"],
    alpha=0.5, color="grey")
axes[0,2].set_title("AveRooms")

axes[0,3].scatter(x=X_testResiduals["AveBedrms"],
    y=X_testResiduals["MedHouseVal"],
    alpha=0.5, color="grey")
axes[0,3].set_title("AveBedrms")

axes[1,0].scatter(x=X_testResiduals["Population"],
    y=X_testResiduals["MedHouseVal"],
    alpha=0.5, color="grey")
axes[1,0].set_title("Population")

axes[1,1].scatter(x=X_testResiduals["AveOccup"],
    y=X_testResiduals["MedHouseVal"],
    alpha=0.5, color="grey")
axes[1,1].set_title("AveOccup")

axes[1,2].scatter(x=X_testResiduals["Latitude"],
    y=X_testResiduals["MedHouseVal"],
    alpha=0.5, color="grey")
axes[1,2].set_title("Latitude")

axes[1,3].scatter(x=X_testResiduals["Longitude"],
    y=X_testResiduals["MedHouseVal"],
    alpha=0.5, color="grey")
axes[1,3].set_title("Longitude")
# Out:
# Text(0.5, 1.0, 'Longitude')
